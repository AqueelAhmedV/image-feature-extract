# %%
from huggingface_hub import notebook_login, HfApi

notebook_login()

# Verify login
api = HfApi()
user_info = api.whoami()
print(f"Logged in as: {user_info['name']}")
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…
# ---------------------------------------------------------------------------
# LocalTokenNotFoundError                   Traceback (most recent call last)
# Cell In[1], line 7
#       5 # Verify login
#       6 api = HfApi()
# ----> 7 user_info = api.whoami()
#       8 print(f"Logged in as: {user_info['name']}")
#
# File d:\Projects\amazonMl\amex\student_resource 3\venv\lib\site-packages\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File d:\Projects\amazonMl\amex\student_resource 3\venv\lib\site-packages\huggingface_hub\hf_api.py:1502, in HfApi.whoami(self, token)
#    1488 @validate_hf_hub_args
#    1489 def whoami(self, token: Union[bool, str, None] = None) -> Dict:
#    1490     """
#    1491     Call HF API to know "whoami".
#    1492
#    (...)
#    1498             To disable authentication, pass `False`.
#    1499     """
#    1500     r = get_session().get(
#    1501         f"{self.endpoint}/api/whoami-v2",
# -> 1502         headers=self._build_hf_headers(
#    1503             # If `token` is provided and not `None`, it will be used by default.
#    1504             # Otherwise, the token must be retrieved from cache or env variable.
#    1505             token=(token or self.token or True),
#    1506         ),
#    1507     )
#    1508     try:
#    1509         hf_raise_for_status(r)
#
# File d:\Projects\amazonMl\amex\student_resource 3\venv\lib\site-packages\huggingface_hub\hf_api.py:9072, in HfApi._build_hf_headers(self, token, is_write_action, library_name, library_version, user_agent)
#    9069 if token is None:
#    9070     # Cannot do `token = token or self.token` as token can be `False`.
#    9071     token = self.token
# -> 9072 return build_hf_headers(
#    9073     token=token,
#    9074     is_write_action=is_write_action,
#    9075     library_name=library_name or self.library_name,
#    9076     library_version=library_version or self.library_version,
#    9077     user_agent=user_agent or self.user_agent,
#    9078     headers=self.headers,
#    9079 )
#
# File d:\Projects\amazonMl\amex\student_resource 3\venv\lib\site-packages\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File d:\Projects\amazonMl\amex\student_resource 3\venv\lib\site-packages\huggingface_hub\utils\_headers.py:124, in build_hf_headers(token, is_write_action, library_name, library_version, user_agent, headers)
#      48 """
#      49 Build headers dictionary to send in a HF Hub call.
#      50
#    (...)
#     121         If `token=True` but token is not saved locally.
#     122 """
#     123 # Get auth token to send
# --> 124 token_to_send = get_token_to_send(token)
#     125 _validate_token_to_send(token_to_send, is_write_action=is_write_action)
#     127 # Combine headers
#
# File d:\Projects\amazonMl\amex\student_resource 3\venv\lib\site-packages\huggingface_hub\utils\_headers.py:158, in get_token_to_send(token)
#     156 if token is True:
#     157     if cached_token is None:
# --> 158         raise LocalTokenNotFoundError(
#     159             "Token is required (`token=True`), but no token found. You"
#     160             " need to provide a token or be logged in to Hugging Face with"
#     161             " `huggingface-cli login` or `huggingface_hub.login`. See"
#     162             " https://huggingface.co/settings/tokens."
#     163         )
#     164     return cached_token
#     166 # Case implicit use of the token is forbidden by env variable
#
# LocalTokenNotFoundError: Token is required (`token=True`), but no token found. You need to provide a token or be logged in to Hugging Face with `huggingface-cli login` or `huggingface_hub.login`. See https://huggingface.co/settings/tokens.

# %%
from huggingface_hub import snapshot_download
from pathlib import Path

# notebook_login()

mistral_models_path = Path.home().joinpath('mistral_models', '7B-Instruct-v0.3')
mistral_models_path.mkdir(parents=True, exist_ok=True)

snapshot_download(repo_id="mistralai/Mistral-7B-Instruct-v0.3", allow_patterns=["params.json", "consolidated.safetensors", "tokenizer.model.v3"], local_dir=mistral_models_path)
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File d:\Projects\amazonMl\amex\student_resource 3\venv\lib\site-packages\huggingface_hub\utils\_errors.py:304, in hf_raise_for_status(response, endpoint_name)
#     303 try:
# --> 304     response.raise_for_status()
#     305 except HTTPError as e:
#
# File d:\Projects\amazonMl\amex\student_resource 3\venv\lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.3/resolve/e0bc86c23ce5aae1db576c8cca6f06f1f73af2db/consolidated.safetensors
#
# The above exception was the direct cause of the following exception:
#
# GatedRepoError                            Traceback (most recent call last)
# Cell In[5], line 9
#       6 mistral_models_path = Path.home().joinpath('mistral_models', '7B-Instruct-v0.3')
#       7 mistral_models_path.mkdir(parents=True, exist_ok=True)
# ----> 9 snapshot_download(repo_id="mistralai/Mistral-7B-Instruct-v0.3", allow_patterns=["params.json", "consolidated.safetensors", "tokenizer.model.v3"], local_dir=mistral_models_path)
#
# File d:\Projects\amazonMl\amex\student_resource 3\venv\lib\site-packages\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File d:\Projects\amazonMl\amex\student_resource 3\venv\lib\site-packages\huggingface_hub\_snapshot_download.py:299, in snapshot_download(repo_id, repo_type, revision, cache_dir, local_dir, library_name, library_version, user_agent, proxies, etag_timeout, force_download, token, local_files_only, allow_patterns, ignore_patterns, max_workers, tqdm_class, headers, endpoint, local_dir_use_symlinks, resume_download)
#     297         _inner_hf_hub_download(file)
#     298 else:
# --> 299     thread_map(
#     300         _inner_hf_hub_download,
#     301         filtered_repo_files,
#     302         desc=f"Fetching {len(filtered_repo_files)} files",
#     303         max_workers=max_workers,
#     304         # User can use its own tqdm class or the default one from `huggingface_hub.utils`
#     305         tqdm_class=tqdm_class or hf_tqdm,
#     306     )
#     308 if local_dir is not None:
#     309     return str(os.path.realpath(local_dir))
#
# File d:\Projects\amazonMl\amex\student_resource 3\venv\lib\site-packages\tqdm\contrib\concurrent.py:69, in thread_map(fn, *iterables, **tqdm_kwargs)
#      55 """
#      56 Equivalent of `list(map(fn, *iterables))`
#      57 driven by `concurrent.futures.ThreadPoolExecutor`.
#    (...)
#      66     [default: max(32, cpu_count() + 4)].
#      67 """
#      68 from concurrent.futures import ThreadPoolExecutor
# ---> 69 return _executor_map(ThreadPoolExecutor, fn, *iterables, **tqdm_kwargs)
#
# File d:\Projects\amazonMl\amex\student_resource 3\venv\lib\site-packages\tqdm\contrib\concurrent.py:51, in _executor_map(PoolExecutor, fn, *iterables, **tqdm_kwargs)
#      47 with ensure_lock(tqdm_class, lock_name=lock_name) as lk:
#      48     # share lock in case workers are already using `tqdm`
#      49     with PoolExecutor(max_workers=max_workers, initializer=tqdm_class.set_lock,
#      50                       initargs=(lk,)) as ex:
# ---> 51         return list(tqdm_class(ex.map(fn, *iterables, chunksize=chunksize), **kwargs))
#
# File d:\Projects\amazonMl\amex\student_resource 3\venv\lib\site-packages\tqdm\std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File C:\Python310\lib\concurrent\futures\_base.py:609, in Executor.map.<locals>.result_iterator()
#     606 while fs:
#     607     # Careful not to keep a reference to the popped future
#     608     if timeout is None:
# --> 609         yield fs.pop().result()
#     610     else:
#     611         yield fs.pop().result(end_time - time.monotonic())
#
# File C:\Python310\lib\concurrent\futures\_base.py:446, in Future.result(self, timeout)
#     444     raise CancelledError()
#     445 elif self._state == FINISHED:
# --> 446     return self.__get_result()
#     447 else:
#     448     raise TimeoutError()
#
# File C:\Python310\lib\concurrent\futures\_base.py:391, in Future.__get_result(self)
#     389 if self._exception:
#     390     try:
# --> 391         raise self._exception
#     392     finally:
#     393         # Break a reference cycle with the exception in self._exception
#     394         self = None
#
# File C:\Python310\lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File d:\Projects\amazonMl\amex\student_resource 3\venv\lib\site-packages\huggingface_hub\_snapshot_download.py:273, in snapshot_download.<locals>._inner_hf_hub_download(repo_file)
#     272 def _inner_hf_hub_download(repo_file: str):
# --> 273     return hf_hub_download(
#     274         repo_id,
#     275         filename=repo_file,
#     276         repo_type=repo_type,
#     277         revision=commit_hash,
#     278         endpoint=endpoint,
#     279         cache_dir=cache_dir,
#     280         local_dir=local_dir,
#     281         local_dir_use_symlinks=local_dir_use_symlinks,
#     282         library_name=library_name,
#     283         library_version=library_version,
#     284         user_agent=user_agent,
#     285         proxies=proxies,
#     286         etag_timeout=etag_timeout,
#     287         resume_download=resume_download,
#     288         force_download=force_download,
#     289         token=token,
#     290         headers=headers,
#     291     )
#
# File d:\Projects\amazonMl\amex\student_resource 3\venv\lib\site-packages\huggingface_hub\utils\_deprecation.py:101, in _deprecate_arguments.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      99         message += "\n\n" + custom_message
#     100     warnings.warn(message, FutureWarning)
# --> 101 return f(*args, **kwargs)
#
# File d:\Projects\amazonMl\amex\student_resource 3\venv\lib\site-packages\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File d:\Projects\amazonMl\amex\student_resource 3\venv\lib\site-packages\huggingface_hub\file_download.py:1220, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, legacy_cache_layout, resume_download, force_filename, local_dir_use_symlinks)
#    1211     if local_dir_use_symlinks != "auto":
#    1212         warnings.warn(
#    1213             "`local_dir_use_symlinks` parameter is deprecated and will be ignored. "
#    1214             "The process to download files to a local folder has been updated and do "
#    (...)
#    1217             "For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder."
#    1218         )
# -> 1220     return _hf_hub_download_to_local_dir(
#    1221         # Destination
#    1222         local_dir=local_dir,
#    1223         # File info
#    1224         repo_id=repo_id,
#    1225         repo_type=repo_type,
#    1226         filename=filename,
#    1227         revision=revision,
#    1228         # HTTP info
#    1229         endpoint=endpoint,
#    1230         etag_timeout=etag_timeout,
#    1231         headers=headers,
#    1232         proxies=proxies,
#    1233         token=token,
#    1234         # Additional options
#    1235         cache_dir=cache_dir,
#    1236         force_download=force_download,
#    1237         local_files_only=local_files_only,
#    1238     )
#    1239 else:
#    1240     return _hf_hub_download_to_cache_dir(
#    1241         # Destination
#    1242         cache_dir=cache_dir,
#    (...)
#    1256         force_download=force_download,
#    1257     )
#
# File d:\Projects\amazonMl\amex\student_resource 3\venv\lib\site-packages\huggingface_hub\file_download.py:1469, in _hf_hub_download_to_local_dir(local_dir, repo_id, repo_type, filename, revision, endpoint, etag_timeout, headers, proxies, token, cache_dir, force_download, local_files_only)
#    1467         return str(paths.file_path)
#    1468     # Otherwise => raise
# -> 1469     _raise_on_head_call_error(head_call_error, force_download, local_files_only)
#    1471 # From now on, etag, commit_hash, url and size are not None.
#    1472 assert etag is not None, "etag must have been retrieved from server"
#
# File d:\Projects\amazonMl\amex\student_resource 3\venv\lib\site-packages\huggingface_hub\file_download.py:1855, in _raise_on_head_call_error(head_call_error, force_download, local_files_only)
#    1849     raise LocalEntryNotFoundError(
#    1850         "Cannot find the requested files in the disk cache and outgoing traffic has been disabled. To enable"
#    1851         " hf.co look-ups and downloads online, set 'local_files_only' to False."
#    1852     )
#    1853 elif isinstance(head_call_error, RepositoryNotFoundError) or isinstance(head_call_error, GatedRepoError):
#    1854     # Repo not found or gated => let's raise the actual error
# -> 1855     raise head_call_error
#    1856 else:
#    1857     # Otherwise: most likely a connection issue or Hub downtime => let's warn the user
#    1858     raise LocalEntryNotFoundError(
#    1859         "An error happened while trying to locate the file on the Hub and we cannot find the requested files"
#    1860         " in the local cache. Please check your connection and try again or make sure your Internet connection"
#    1861         " is on."
#    1862     ) from head_call_error
#
# File d:\Projects\amazonMl\amex\student_resource 3\venv\lib\site-packages\huggingface_hub\file_download.py:1752, in _get_metadata_or_catch_error(repo_id, filename, repo_type, revision, endpoint, proxies, etag_timeout, headers, token, local_files_only, relative_filename, storage_folder)
#    1750 try:
#    1751     try:
# -> 1752         metadata = get_hf_file_metadata(
#    1753             url=url, proxies=proxies, timeout=etag_timeout, headers=headers, token=token
#    1754         )
#    1755     except EntryNotFoundError as http_error:
#    1756         if storage_folder is not None and relative_filename is not None:
#    1757             # Cache the non-existence of the file
#
# File d:\Projects\amazonMl\amex\student_resource 3\venv\lib\site-packages\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File d:\Projects\amazonMl\amex\student_resource 3\venv\lib\site-packages\huggingface_hub\file_download.py:1674, in get_hf_file_metadata(url, token, proxies, timeout, library_name, library_version, user_agent, headers)
#    1671 headers["Accept-Encoding"] = "identity"  # prevent any compression => we want to know the real size of the file
#    1673 # Retrieve metadata
# -> 1674 r = _request_wrapper(
#    1675     method="HEAD",
#    1676     url=url,
#    1677     headers=headers,
#    1678     allow_redirects=False,
#    1679     follow_relative_redirects=True,
#    1680     proxies=proxies,
#    1681     timeout=timeout,
#    1682 )
#    1683 hf_raise_for_status(r)
#    1685 # Return
#
# File d:\Projects\amazonMl\amex\student_resource 3\venv\lib\site-packages\huggingface_hub\file_download.py:376, in _request_wrapper(method, url, follow_relative_redirects, **params)
#     374 # Recursively follow relative redirects
#     375 if follow_relative_redirects:
# --> 376     response = _request_wrapper(
#     377         method=method,
#     378         url=url,
#     379         follow_relative_redirects=False,
#     380         **params,
#     381     )
#     383     # If redirection, we redirect only relative paths.
#     384     # This is useful in case of a renamed repository.
#     385     if 300 <= response.status_code <= 399:
#
# File d:\Projects\amazonMl\amex\student_resource 3\venv\lib\site-packages\huggingface_hub\file_download.py:400, in _request_wrapper(method, url, follow_relative_redirects, **params)
#     398 # Perform request and return if status_code is not in the retry list.
#     399 response = get_session().request(method=method, url=url, **params)
# --> 400 hf_raise_for_status(response)
#     401 return response
#
# File d:\Projects\amazonMl\amex\student_resource 3\venv\lib\site-packages\huggingface_hub\utils\_errors.py:321, in hf_raise_for_status(response, endpoint_name)
#     317 elif error_code == "GatedRepo":
#     318     message = (
#     319         f"{response.status_code} Client Error." + "\n\n" + f"Cannot access gated repo for url {response.url}."
#     320     )
# --> 321     raise GatedRepoError(message, response) from e
#     323 elif error_message == "Access to this resource is disabled.":
#     324     message = (
#     325         f"{response.status_code} Client Error."
#     326         + "\n\n"
#    (...)
#     329         + "Access to this resource is disabled."
#     330     )
#
# GatedRepoError: 401 Client Error. (Request ID: Root=1-66e5d0c9-386da6e852ac584a3896b282;cfe252f1-6c86-492f-a729-844a08a23e9f)
#
# Cannot access gated repo for url https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.3/resolve/e0bc86c23ce5aae1db576c8cca6f06f1f73af2db/consolidated.safetensors.
# Access to model mistralai/Mistral-7B-Instruct-v0.3 is restricted. You must have access to it and be authenticated to access it. Please log in.
